# %%
# import pandas
import pandas as pd

# %%
# Name: Hector Enriquez 
# Assignment # 4

# %%
# import sqlalchemy
from sqlalchemy import create_engine

# connection string format: mysql+<driver>://username:password@databaseserver/databasename
connection_string = 'mysql+mysqlconnector://root:000@localhost/mydb'
connection = create_engine(connection_string)

# %%
# SQL query
query = "select d.department_name as Department, sum(e.salary) as TotalSalary \
from employee e, department d \
where e.department_id = d.department_id \
group by d.department_name"

# extract mysql query result into pandas data frame
df = pd.read_sql(query, connection)

# print 5 rows of data frame
print(df.head())

# import matplotlib
import matplotlib.pyplot as plt


# plot bar graph
plt.bar(df.Department, df.TotalSalary)
plt.show()
47
# Out:
#         Department  TotalSalary
# 0        Marketing     135650.0
# 1       Accounting      71000.0
# 2  Human Resources      74000.0
# 3            Legal     102500.0
# 47

# %%
query = "SELECT d.DEPARTMENT_NAME, COUNT(e.EMPLOYEE_ID) AS total_employees \
FROM department d \
LEFT JOIN employee e ON d.DEPARTMENT_ID = e.DEPARTMENT_ID \
GROUP BY d.DEPARTMENT_NAME" \

# extract mysql query result into pandas data frame
df = pd.read_sql(query, connection)

# print 5 rows of data frame
print(df.head())

# import matplotlib
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.bar(df['DEPARTMENT_NAME'], df['total_employees'], color='skyblue')
plt.xlabel('Department Name')
plt.ylabel('Total Employees')
plt.title('Total Employees per Department')
plt.xticks(rotation=45)
plt.tight_layout()

# Show the plot
plt.show()



plt.show()
47
# Out:
#    DEPARTMENT_NAME  total_employees
# 0       Accounting                2
# 1  Human Resources                2
# 2            Legal                3
# 3        Marketing                3
# 4   Administration                0
# 47
